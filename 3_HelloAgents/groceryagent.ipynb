# %%
# Necessary imports
from agents import Agent, Runner, trace
import asyncio
import os
from dotenv import load_dotenv

# %%
# Load OpenAI API Key
load_dotenv()
# Out:
# True

# %%
ginstructions="""
You are a smart kitchen assistant.

When given a list of ingredients at home, do the following:
1. Suggest 2 recipes the user can make with these ingredients.
2. For each recipe, provide:
   - A recipe name
   - A short one-line description
   - The required ingredients
3. Identify what ingredients are missing and generate a grouped grocery list.
"""

# %%
# Create the Smart Grocery Agent
agent = Agent(
    name="Smart Grocery Agent",
    instructions=ginstructions,
    model="gpt-4o-mini",  
)
print(agent)
# Out:
# Agent(name='Smart Grocery Agent', handoff_description=None, tools=[], mcp_servers=[], mcp_config={}, instructions='\nYou are a smart kitchen assistant.\n\nWhen given a list of ingredients at home, do the following:\n1. Suggest 2 recipes the user can make with these ingredients.\n2. For each recipe, provide:\n   - A recipe name\n   - A short one-line description\n   - The required ingredients\n3. Identify what ingredients are missing and generate a grouped grocery list.\n', prompt=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, metadata=None, store=None, include_usage=None, response_include=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True)

# %%
# Function to call the agent
async def get_suggestions(user_ingredients: str):
    result = await Runner.run(agent, user_ingredients)
    return result.final_output

# %%
# To retrieve the result from the coroutine object, we need to use the await keyword
 
user_input = "eggs, milk, butter and bread";
response = await (get_suggestions(user_input))

# %%
print(response)


# Define a chat function, there are two roles in the chat: system and user
# Out:
# Here are two delicious recipes you can make with the ingredients you have:
#
# ### Recipe 1: French Toast
# **Description:** Classic French toast made with eggs and milk, served warm and delicious.
#
# **Required Ingredients:**
# - 2 eggs
# - 1 cup milk
# - 4 slices of bread
# - 2 tablespoons butter
# - Optional: cinnamon, vanilla, maple syrup for serving
#
# ### Recipe 2: Scrambled Eggs on Toast
# **Description:** Creamy scrambled eggs served on toasted bread, perfect for breakfast.
#
# **Required Ingredients:**
# - 4 eggs
# - 2 tablespoons milk
# - 2 tablespoons butter
# - 4 slices of bread
# - Salt and pepper to taste
#
# ### Missing Ingredients:
# - Cinnamon (optional for French toast)
# - Vanilla extract (optional for French toast)
# - Maple syrup (optional for French toast)
# - Salt (for scrambled eggs)
# - Pepper (for scrambled eggs)
#
# ### Grocery List:
# - Cinnamon (optional)
# - Vanilla extract (optional)
# - Maple syrup (optional)
# - Salt
# - Pepper
#
# Enjoy your cooking!

# %%
# Can see the traces from https://platform.openai.com/traces by logging into your account

with trace("Grocery Agent"):
   user_input = "rice, green vegetables, wheat flour";
   response = await (get_suggestions(user_input))
   print(response)
# Out:
# Here are two recipes you can make with the ingredients you have:
#
# ### Recipe 1: Vegetable Stir-Fried Rice
# **Description:** A quick and nutritious dish featuring rice and assorted green vegetables, perfect for a weeknight dinner.
#
# **Required Ingredients:**
# - Rice
# - Green vegetables (e.g., spinach, broccoli, or green beans)
# - Soy sauce or other seasonings (optional)
# - Oil (for frying)
# - Garlic and onion (optional)
#
# ### Recipe 2: Vegetable Paratha
# **Description:** Delicious Indian flatbreads stuffed with a mixture of wheat flour and finely chopped green vegetables.
#
# **Required Ingredients:**
# - Wheat flour
# - Green vegetables (e.g., spinach, cabbage, or peas)
# - Water (for kneading)
# - Oil or ghee (for cooking)
# - Spices (like cumin, coriander, or salt) (optional)
#
# ### Missing Ingredients:
# 1. Soy sauce (for stir-fried rice)
# 2. Garlic and onion (for added flavor in stir-fried rice)
# 3. Water (for kneading dough)
# 4. Oil or ghee (if not available)
# 5. Spices (for paratha and stir-fried rice)
#
# ### Grocery List:
# - Soy sauce
# - Garlic
# - Onion
# - Oil or ghee
# - Spices (cumin, coriander, salt)
#
# Feel free to ask if you'd like more recipes or variations!
