# %% [markdown]
# ### List

# %%
# Creating a list of fruits
fruits = ["apple", "banana", "cherry"]

# Accessing items
print(fruits[0])  # Output: apple
print(fruits[1])  # Output: banana

# Adding an item
fruits.append("orange")
print(fruits)  # Output: ['apple', 'banana', 'cherry', 'orange']

# Removing an item
fruits.remove("banana")
print(fruits)  # Output: ['apple', 'cherry', 'orange']
# Out:
# apple
# banana
# ['apple', 'banana', 'cherry', 'orange']
# ['apple', 'cherry', 'orange']

# %% [markdown]
# ### Dictionary

# %%
# Creating a dictionary with some information about a person
person = {
    "name": "Alice",
    "age": 25,
    "city": "New York"
}

# Accessing values by key
print(person["name"])  # Output: Alice
print(person["age"])   # Output: 25

# Adding a new key-value pair
person["job"] = "Engineer"
print(person)  # Output: {'name': 'Alice', 'age': 25, 'city': 'New York', 'job': 'Engineer'}

# Changing a value
person["city"] = "San Francisco"
print(person)  # Output: {'name': 'Alice', 'age': 25, 'city': 'San Francisco', 'job': 'Engineer'}

# Using get() without a default value
print(person.get("name"))  # Output: Alice
print(person.get("country"))  # Output: None (since 'country' is not a key)

# Using get() with a default value
print(person.get("country", "USA"))  # Output: USA (default value provided)
# Out:
# Alice
# 25
# {'name': 'Alice', 'age': 25, 'city': 'New York', 'job': 'Engineer'}
# {'name': 'Alice', 'age': 25, 'city': 'San Francisco', 'job': 'Engineer'}
# Alice
# None
# USA

# %% [markdown]
# ### Set

# %%
# Creating a set of colors
colors = {"red", "green", "blue"}

# Adding an item
colors.add("yellow")
print(colors)  # Output: {'red', 'green', 'blue', 'yellow'}

# Trying to add a duplicate item
colors.add("red")
print(colors)  # Output: {'red', 'green', 'blue', 'yellow'} (no duplicate)

# Removing an item
colors.remove("green")
print(colors)  # Output: {'red', 'blue', 'yellow'}
# Out:
# {'blue', 'green', 'red', 'yellow'}
# {'blue', 'green', 'red', 'yellow'}
# {'blue', 'red', 'yellow'}

# %% [markdown]
# ### Tuple

# %%
print("=== 1. Creating Tuples ===")
t1 = (10, 20, 30)
t2 = ("Renuka", 25, 5.6, True)
t3 = (10)   # single-element tuple

print(t1)
print(t2)
print("Single element tuple:", t3)
print()

# ----------------------------------------------------

print("=== 2. Indexing ===")
t = (10, 20, 30, 40)
print("First item:", t[0])
print("Last item:", t[-1])
print()

# ----------------------------------------------------

print("=== 3. Slicing ===")
t = (10, 20, 30, 40, 50)
print("Slice 1 to 4:", t[1:4])
print("Last 3 items:", t[-3:])
print()

# ----------------------------------------------------

print("=== 4. Tuple is Read-Only ===")
t = (10, 20, 30)
print("Original tuple:", t)
try:
    t[0] = 99
except Exception as e:
    print("Error:", e)
print()

# ----------------------------------------------------

print("=== 5. Looping Through Tuple ===")
t = (1, 2, 3)
for x in t:
    print(x)
print()

# ----------------------------------------------------

print("=== 6. Membership Test ===")
t = (10, 20, 30)
print("Is 20 in tuple?", 20 in t)
print("Is 50 in tuple?", 50 in t)
print()

# ----------------------------------------------------

print("=== 7. Tuple Functions ===")
t = (5, 8, 2, 8)
print("Length:", len(t))
print("Min:", min(t))
print("Max:", max(t))
print("Count of 8:", t.count(8))
print("Index of 5:", t.index(5))
print()

# ----------------------------------------------------

print("=== 8. Packing & Unpacking ===")
t = 10, 20, 30   # packing
a, b, c = t      # unpacking
print("Packed tuple:", t)
print("Unpacked values:", a, b, c)
print()

print("=== Tuple Demo Completed! ===")
# Out:
# === 1. Creating Tuples ===
# (10, 20, 30)
# ('Renuka', 25, 5.6, True)
# Single element tuple: 10
#
# === 2. Indexing ===
# First item: 10
# Last item: 40
#
# === 3. Slicing ===
# Slice 1 to 4: (20, 30, 40)
# Last 3 items: (30, 40, 50)
#
# === 4. Tuple is Read-Only ===
# Original tuple: (10, 20, 30)
# Error: 'tuple' object does not support item assignment
#
# === 5. Looping Through Tuple ===
# 1
# 2
# 3
#
# === 6. Membership Test ===
# Is 20 in tuple? True
# Is 50 in tuple? False
#
# === 7. Tuple Functions ===
# Length: 4
# Min: 2
# Max: 8
# Count of 8: 2
# Index of 5: 0
#
# === 8. Packing & Unpacking ===
# Packed tuple: (10, 20, 30)
# Unpacked values: 10 20 30
#
# === Tuple Demo Completed! ===
